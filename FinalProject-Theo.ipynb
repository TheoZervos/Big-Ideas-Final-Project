# %% [markdown]
# # Finding the Best Neighborhood in Relation to Median Age at Death
# Health is a major component to happiness. Those who live longer tend to lead happier, healthier lives. Areas where young deaths are common tend to have higher crime and/or be more dangerous areas. In this notebook, I will be determining what the best area in Pittsburgh to live is based off of the median age at death. Areas with a higher median age at death will be the safer, happier, and healthier areas in Pittsburgh, while those with a lower median may have higher crime and/or be areas where good health is hard to come by.

# %% [markdown]
# ## Identifying High and Low Median Age at Death Areas
# Let's first find the median age at death for all the neighborhoods in Pittsburgh...

# %%
import pandas as pd
data = pd.read_csv('nhoodmedianage20112015.csv', sep='\s*,\s*', engine='python')

pd.set_option('display.max_rows', 999)

data[['NEIGHBORHOOD', 'TOTAL MD AGE AT DEATH']]
# Out:
#                                NEIGHBORHOOD  TOTAL MD AGE AT DEATH
# 0                               SOUTH SHORE                    0.0
# 1                                   CHATEAU                    NaN
# 2                               NORTH SHORE                   80.0
# 3                            ALLEGHENY WEST                   65.0
# 4                               SAINT CLAIR                   67.5
# 5                                  WEST END                   77.5
# 6                                    ESPLEN                   71.7
# 7                         ARLINGTON HEIGHTS                   63.7
# 8                            STRIP DISTRICT                   72.5
# 9                                 FAIRYWOOD                   53.3
# 10                                     HAYS                   78.3
# 11                MOUNT OLIVER NEIGHBORHOOD                   75.0
# 12                            EAST CARNEGIE                   80.0
# 13                            REGENT SQUARE                   76.7
# 14                     CALIFORNIA-KIRKBRIDE                   69.3
# 15                           CHARTIERS CITY                   76.9
# 16                               FRIENDSHIP                   71.1
# 17                                    BLUFF                   70.0
# 18                         ALLEGHENY CENTER                   81.7
# 19                                  BON AIR                   78.5
# 20                          CENTRAL OAKLAND                   84.0
# 21                                RIDGEMONT                   79.3
# 22                        NORTHVIEW HEIGHTS                   68.0
# 23                                 FINEVIEW                   70.8
# 24                              SUMMER HILL                   78.3
# 25                            HOMEWOOD WEST                   80.3
# 26                            SPRING GARDEN                   71.8
# 27                           SWISSHELM PARK                   83.1
# 28                            NEW HOMESTEAD                   83.4
# 29                                  OAKWOOD                   78.8
# 30                              POLISH HILL                   72.2
# 31                       POINT BREEZE NORTH                   73.2
# 32                        BEDFORD DWELLINGS                   71.4
# 33                             WEST OAKLAND                   79.5
# 34                                ARLINGTON                   73.7
# 35                          TERRACE VILLAGE                   71.2
# 36                            SOUTH OAKLAND                   77.1
# 37                                  WINDGAP                   77.5
# 38                               MANCHESTER                   67.4
# 39                      UPPER LAWRENCEVILLE                   73.7
# 40                                  ELLIOTT                   72.0
# 41                              BELTZHOOVER                   76.6
# 42                                ALLENTOWN                   66.5
# 43                               GLEN HAZEL                   79.8
# 44                CENTRAL BUSINESS DISTRICT                   73.9
# 45                         DUQUESNE HEIGHTS                   79.2
# 46                      LOWER LAWRENCEVILLE                   73.9
# 47                        CENTRAL NORTHSIDE                   71.7
# 48                  TROY HILL/HERR'S ISLAND                   70.3
# 49                           EAST ALLEGHENY                   66.2
# 50                              MORNINGSIDE                   77.8
# 51                                 WESTWOOD                   77.0
# 52                                  LARIMER                   75.3
# 53                             POINT BREEZE                   85.1
# 54                               EAST HILLS                   70.9
# 55                              MIDDLE HILL                   72.4
# 56                           HOMEWOOD NORTH                   75.1
# 57                          CRAFTON HEIGHTS                   73.5
# 58                                KNOXVILLE                   71.7
# 59                     SPRING HILL-CITYVIEW                   77.8
# 60                               UPPER HILL                   81.7
# 61                                 GARFIELD                   73.5
# 62                         CRAWFORD ROBERTS                   74.8
# 63                           HOMEWOOD SOUTH                   76.5
# 64                              PERRY NORTH                   74.6
# 65                            HIGHLAND PARK                   79.2
# 66                            LINCOLN PLACE                   79.8
# 67                         SOUTHSIDE SLOPES                   77.2
# 68                      SQUIRREL HILL NORTH                   85.0
# 69                                 SHERADEN                   72.0
# 70                       MARSHALL-SHADELAND                   70.0
# 71                               BANKSVILLE                   85.5
# 72                              PERRY SOUTH                   76.4
# 73                                HAZELWOOD                   72.2
# 74                          SOUTHSIDE FLATS                   78.4
# 75                          STANTON HEIGHTS                   80.5
# 76                            NORTH OAKLAND                   85.6
# 77                                OVERBROOK                   82.2
# 78                               GREENFIELD                   79.2
# 79                    CENTRAL LAWRENCEVILLE                   81.3
# 80                             EAST LIBERTY                   73.0
# 81                 LINCOLN-LEMINGTON-BELMAR                   78.8
# 82                               BLOOMFIELD                   78.2
# 83                                SHADYSIDE                   82.1
# 84                                BEECHVIEW                   78.9
# 85                         MOUNT WASHINGTON                   76.3
# 86                         BRIGHTON HEIGHTS                   78.9
# 87                                  CARRICK                   75.9
# 88                                BROOKLINE                   77.8
# 89                      SQUIRREL HILL SOUTH                   85.9
# 90                                      NaN                    NaN
# 91  *Total includes Other and Unknown race.                    NaN

# %% [markdown]
# OOF. Let's make a bar graph so it's esier to see the spread. This graph will be in order from lowestto highest median age at death

# %%
ax = data.plot.bar(y = 'TOTAL MD AGE AT DEATH', rot=0, figsize=(20,10))

# %% [markdown]
# Now, lets find the 10 neigborhoods with the highest median age at death neighborhoods...

# %%
data[['NEIGHBORHOOD', 'TOTAL MD AGE AT DEATH']].nlargest(10, 'TOTAL MD AGE AT DEATH',keep='first')
# Out:
#            NEIGHBORHOOD  TOTAL MD AGE AT DEATH
# 89  SQUIRREL HILL SOUTH                   85.9
# 76        NORTH OAKLAND                   85.6
# 71           BANKSVILLE                   85.5
# 53         POINT BREEZE                   85.1
# 68  SQUIRREL HILL NORTH                   85.0
# 20      CENTRAL OAKLAND                   84.0
# 28        NEW HOMESTEAD                   83.4
# 27       SWISSHELM PARK                   83.1
# 77            OVERBROOK                   82.2
# 83            SHADYSIDE                   82.1

# %% [markdown]
# Now lets find the gap between the highest and lowest value in this table of the 10 highest median age at death neighborhoods...

# %%
from decimal import Decimal, getcontext
gap = Decimal('85.9') - Decimal('82.1')
print(gap)
# Out:
# 3.8

# %% [markdown]
# Almost done! Now, let's find the 10 neighborhoods with the lowest median age at death (due to missing data in dataset, neighborhood SOUTH SHORE should be **IGNORED**)

# %%
data[['NEIGHBORHOOD', 'TOTAL MD AGE AT DEATH']].nsmallest(11, 'TOTAL MD AGE AT DEATH',keep='first')
# Out:
#             NEIGHBORHOOD  TOTAL MD AGE AT DEATH
# 0            SOUTH SHORE                    0.0
# 9              FAIRYWOOD                   53.3
# 7      ARLINGTON HEIGHTS                   63.7
# 3         ALLEGHENY WEST                   65.0
# 49        EAST ALLEGHENY                   66.2
# 42             ALLENTOWN                   66.5
# 38            MANCHESTER                   67.4
# 4            SAINT CLAIR                   67.5
# 22     NORTHVIEW HEIGHTS                   68.0
# 14  CALIFORNIA-KIRKBRIDE                   69.3
# 17                 BLUFF                   70.0

# %% [markdown]
# Finally, lets find the gap between the highest and lowest value in this table of the 10 lowest median age at death neighborhoods...

# %%
gap = Decimal('70.0') - Decimal('53.3')
print(gap)
# Out:
# 16.7

# %% [markdown]
# # Analyzing Interesting Anomalies in Data
# As you can see, the values of the neighborhoods with the highest median age at death are all relitively similar, with a gap of 3.8 between the highest and lowest median age at death. The values of the neighborhoods with the lowest median age at death, however, seem to vary, with a 16.7 year gap in age between the highest and lowest median age at death. Why is that? Let's look at more data on the neighborhood of FAIRYWOOD.

# %%
data.iloc[9]
# Out:
# NEIGHBORHOOD             FAIRYWOOD
# BLACKdeaths                   11.0
# Black MD AGE AT DEATH         62.5
# WHITEdeaths                    9.0
# White MD AGE AT DEATH         42.5
# TOTALdeaths*                  21.0
# TOTAL MD AGE AT DEATH         53.3
# Name: 9, dtype: object

# %% [markdown]
# After looking at more data, we can see that we are finding the median for only 21 deaths. Let's see if that is that is above or below the average for this data set... **(In this data set TOTALdeaths* counts all deaths including deaths from Other and Uknown races.)**

# %%
data['TOTALdeaths*'].mean()
# Out:
# 171.2111111111111

# %% [markdown]
# This average seems WAY higher than the average for FAIRYWOOD. Let's see if this is being weighted by just one large total death count, or if FAIRYWOOD has a very low total death count compared to most of the other neighborhoods.

# %%
data[['NEIGHBORHOOD', 'TOTALdeaths*']].nlargest(50, 'TOTALdeaths*', keep='first')
# Out:
#                  NEIGHBORHOOD  TOTALdeaths*
# 89        SQUIRREL HILL SOUTH         802.0
# 88                  BROOKLINE         750.0
# 87                    CARRICK         678.0
# 86           BRIGHTON HEIGHTS         496.0
# 85           MOUNT WASHINGTON         476.0
# 84                  BEECHVIEW         434.0
# 83                  SHADYSIDE         406.0
# 82                 BLOOMFIELD         394.0
# 81   LINCOLN-LEMINGTON-BELMAR         389.0
# 80               EAST LIBERTY         364.0
# 79      CENTRAL LAWRENCEVILLE         358.0
# 78                 GREENFIELD         337.0
# 77                  OVERBROOK         289.0
# 76              NORTH OAKLAND         279.0
# 75            STANTON HEIGHTS         278.0
# 74            SOUTHSIDE FLATS         277.0
# 73                  HAZELWOOD         261.0
# 72                PERRY SOUTH         259.0
# 71                 BANKSVILLE         253.0
# 70         MARSHALL-SHADELAND         252.0
# 69                   SHERADEN         248.0
# 68        SQUIRREL HILL NORTH         242.0
# 67           SOUTHSIDE SLOPES         220.0
# 66              LINCOLN PLACE         217.0
# 65              HIGHLAND PARK         213.0
# 64                PERRY NORTH         205.0
# 63             HOMEWOOD SOUTH         204.0
# 62           CRAWFORD ROBERTS         202.0
# 61                   GARFIELD         198.0
# 60                 UPPER HILL         191.0
# 59       SPRING HILL-CITYVIEW         189.0
# 58                  KNOXVILLE         188.0
# 57            CRAFTON HEIGHTS         187.0
# 56             HOMEWOOD NORTH         185.0
# 55                MIDDLE HILL         183.0
# 54                 EAST HILLS         177.0
# 53               POINT BREEZE         175.0
# 52                    LARIMER         174.0
# 51                   WESTWOOD         173.0
# 50                MORNINGSIDE         161.0
# 49             EAST ALLEGHENY         157.0
# 48    TROY HILL/HERR'S ISLAND         151.0
# 47          CENTRAL NORTHSIDE         147.0
# 46        LOWER LAWRENCEVILLE         138.0
# 45           DUQUESNE HEIGHTS         134.0
# 44  CENTRAL BUSINESS DISTRICT         133.0
# 43                 GLEN HAZEL         131.0
# 42                  ALLENTOWN         126.0
# 41                BELTZHOOVER         125.0
# 40                    ELLIOTT         121.0

# %% [markdown]
# Now, after finding the average total death count AND checking to make sure the total death count average is being unfairly weighted by just one area, let's refine out data to find the neighborhoods with the highest and lowest median age at death only in areas with "sufficient" data. For us, this will be a TOTALdeaths* value greater than or equal to 100. We will start by displaying all valid neighborhoods.

# %%
refined_data = data[data['TOTALdeaths*'] > 100]
refined_data
# Out:
#                  NEIGHBORHOOD  BLACKdeaths  Black MD AGE AT DEATH  \
# 36              SOUTH OAKLAND         37.0                   75.7
# 37                    WINDGAP         24.0                   71.2
# 38                 MANCHESTER         97.0                   67.2
# 39        UPPER LAWRENCEVILLE          8.0                   48.3
# 40                    ELLIOTT         28.0                   67.0
# 41                BELTZHOOVER        105.0                   76.1
# 42                  ALLENTOWN         41.0                   55.6
# 43                 GLEN HAZEL         60.0                   80.7
# 44  CENTRAL BUSINESS DISTRICT         33.0                   64.5
# 45           DUQUESNE HEIGHTS          3.0                    NaN
# 46        LOWER LAWRENCEVILLE         20.0                   60.0
# 47          CENTRAL NORTHSIDE         90.0                   72.0
# 48    TROY HILL/HERR'S ISLAND         15.0                   42.5
# 49             EAST ALLEGHENY         51.0                   62.7
# 50                MORNINGSIDE         10.0                   70.0
# 51                   WESTWOOD         12.0                   58.3
# 52                    LARIMER        123.0                   77.3
# 53               POINT BREEZE         13.0                   66.7
# 54                 EAST HILLS        171.0                   71.7
# 55                MIDDLE HILL        174.0                   73.1
# 56             HOMEWOOD NORTH        175.0                   75.3
# 57            CRAFTON HEIGHTS         27.0                   51.2
# 58                  KNOXVILLE         61.0                   61.8
# 59       SPRING HILL-CITYVIEW         34.0                   69.3
# 60                 UPPER HILL        102.0                   77.4
# 61                   GARFIELD        159.0                   71.5
# 62           CRAWFORD ROBERTS        189.0                   75.3
# 63             HOMEWOOD SOUTH        196.0                   76.9
# 64                PERRY NORTH         56.0                   63.5
# 65              HIGHLAND PARK         49.0                   68.7
# 66              LINCOLN PLACE          3.0                    NaN
# 67           SOUTHSIDE SLOPES          9.0                   58.7
# 68        SQUIRREL HILL NORTH          6.0                   75.0
# 69                   SHERADEN         62.0                   62.2
# 70         MARSHALL-SHADELAND         55.0                   60.0
# 71                 BANKSVILLE          4.0                    NaN
# 72                PERRY SOUTH        147.0                   71.6
# 73                  HAZELWOOD         74.0                   68.2
# 74            SOUTHSIDE FLATS         11.0                   74.0
# 75            STANTON HEIGHTS        112.0                   75.6
# 76              NORTH OAKLAND         45.0                   70.9
# 77                  OVERBROOK          4.0                    NaN
# 78                 GREENFIELD          8.0                   65.0
# 79      CENTRAL LAWRENCEVILLE         18.0                   75.0
# 80               EAST LIBERTY        259.0                   71.8
# 81   LINCOLN-LEMINGTON-BELMAR        287.0                   76.7
# 82                 BLOOMFIELD         25.0                   68.0
# 83                  SHADYSIDE         72.0                   81.2
# 84                  BEECHVIEW         35.0                   55.8
# 85           MOUNT WASHINGTON         35.0                   68.1
# 86           BRIGHTON HEIGHTS         56.0                   63.7
# 87                    CARRICK         35.0                   59.4
# 88                  BROOKLINE         13.0                   61.2
# 89        SQUIRREL HILL SOUTH         58.0                   83.2
#
#     WHITEdeaths  White MD AGE AT DEATH  TOTALdeaths*  TOTAL MD AGE AT DEATH
# 36         63.0                   77.5         103.0                   77.1
# 37         80.0                   80.4         104.0                   77.5
# 38         15.0                   70.0         113.0                   67.4
# 39        111.0                   75.5         119.0                   73.7
# 40         91.0                   73.7         121.0                   72.0
# 41         13.0                   76.0         125.0                   76.6
# 42         82.0                   72.1         126.0                   66.5
# 43         69.0                   78.7         131.0                   79.8
# 44         92.0                   77.0         133.0                   73.9
# 45        131.0                   79.3         134.0                   79.2
# 46        118.0                   75.7         138.0                   73.9
# 47         54.0                   73.3         147.0                   71.7
# 48        134.0                   73.8         151.0                   70.3
# 49        100.0                   70.0         157.0                   66.2
# 50        150.0                   78.2         161.0                   77.8
# 51        159.0                   77.8         173.0                   77.0
# 52         45.0                   70.0         174.0                   75.3
# 53        158.0                   85.7         175.0                   85.1
# 54          4.0                    NaN         177.0                   70.9
# 55          6.0                   61.7         183.0                   72.4
# 56          4.0                    NaN         185.0                   75.1
# 57        159.0                   76.0         187.0                   73.5
# 58        121.0                   75.6         188.0                   71.7
# 59        153.0                   79.2         189.0                   77.8
# 60         88.0                   88.4         191.0                   81.7
# 61         36.0                   79.3         198.0                   73.5
# 62         10.0                   70.0         202.0                   74.8
# 63          4.0                    NaN         204.0                   76.5
# 64        144.0                   79.5         205.0                   74.6
# 65        159.0                   83.2         213.0                   79.2
# 66        212.0                   80.3         217.0                   79.8
# 67        208.0                   77.9         220.0                   77.2
# 68        231.0                   85.3         242.0                   85.0
# 69        180.0                   76.8         248.0                   72.0
# 70        191.0                   73.2         252.0                   70.0
# 71        247.0                   85.5         253.0                   85.5
# 72        105.0                   83.3         259.0                   76.4
# 73        184.0                   74.2         261.0                   72.2
# 74        265.0                   78.8         277.0                   78.4
# 75        165.0                   84.0         278.0                   80.5
# 76        227.0                   86.8         279.0                   85.6
# 77        284.0                   82.5         289.0                   82.2
# 78        325.0                   79.6         337.0                   79.2
# 79        338.0                   81.7         358.0                   81.3
# 80         91.0                   78.4         364.0                   73.0
# 81         98.0                   84.7         389.0                   78.8
# 82        362.0                   78.9         394.0                   78.2
# 83        320.0                   82.4         406.0                   82.1
# 84        398.0                   80.2         434.0                   78.9
# 85        433.0                   77.0         476.0                   76.3
# 86        432.0                   80.3         496.0                   78.9
# 87        622.0                   77.0         678.0                   75.9
# 88        723.0                   78.1         750.0                   77.8
# 89        721.0                   86.2         802.0                   85.9

# %% [markdown]
# As we can see, eliminating neighborhoods with "insufficient" data has significantly reduced our dataset size. With this new dataset, we can now find a more reliable answer for the highest and lowest median age at death neighborhoods. Let's start with highest...

# %%
refined_data[['NEIGHBORHOOD', 'TOTAL MD AGE AT DEATH']].nlargest(11, 'TOTAL MD AGE AT DEATH',keep='first')
# Out:
#              NEIGHBORHOOD  TOTAL MD AGE AT DEATH
# 89    SQUIRREL HILL SOUTH                   85.9
# 76          NORTH OAKLAND                   85.6
# 71             BANKSVILLE                   85.5
# 53           POINT BREEZE                   85.1
# 68    SQUIRREL HILL NORTH                   85.0
# 77              OVERBROOK                   82.2
# 83              SHADYSIDE                   82.1
# 60             UPPER HILL                   81.7
# 79  CENTRAL LAWRENCEVILLE                   81.3
# 75        STANTON HEIGHTS                   80.5
# 43             GLEN HAZEL                   79.8

# %% [markdown]
# Now the lowest...

# %%
refined_data[['NEIGHBORHOOD', 'TOTAL MD AGE AT DEATH']].nsmallest(11, 'TOTAL MD AGE AT DEATH',keep='first')
# Out:
#                NEIGHBORHOOD  TOTAL MD AGE AT DEATH
# 49           EAST ALLEGHENY                   66.2
# 42                ALLENTOWN                   66.5
# 38               MANCHESTER                   67.4
# 70       MARSHALL-SHADELAND                   70.0
# 48  TROY HILL/HERR'S ISLAND                   70.3
# 54               EAST HILLS                   70.9
# 47        CENTRAL NORTHSIDE                   71.7
# 58                KNOXVILLE                   71.7
# 40                  ELLIOTT                   72.0
# 69                 SHERADEN                   72.0
# 73                HAZELWOOD                   72.2

# %% [markdown]
# Now, after eliminating areas with insufficint data, we have good idea of what neighborhoods in Pittsburgh have the healthiest population.

# %% [markdown]
# ## Conclusion
# After filtering through the data provided, we have determined that the neighborhood in Pittsburgh with the longest life, and by association the healtiest people, would be Squirrel Hill South. This does not come as to much of a surprise, as Squirrel Hill is known as a very good neighborhood. The place with the lowest life, and by association the least healthy people, is the neighborhood of East Allegheny. With this data we can not determine if the low median age at death is caused by health issues or safety issues, but nonetheless, it is a significant difference between the highest median age at death of South Squirrel Hill.
