# %%
import pandas as pd

tv = pd.read_csv("tobaccovendors.csv")

validzips = ["15201","15203","15206","15207","15208","15211","15213","15217","15219","15222","15224",
"15230","15232","15233","15204","15205","15210","15212","15215","15214","15216","15218","15220","15221",
"15226","15227","15234","15235","15120","15106"]

incity = tv.loc[tv['Zip'].str.slice(0, 5).isin(validzips)]
    
pd.set_option('display.max_rows', 999)

incity
# Out:
#       License_No                       License_Type  Issue_Date  \
# 0       70159035                     Cig/OTP Retail    1/4/2016
# 4       70159043                     Cig/OTP Retail  12/23/2015
# 7       70159049                     Cig/OTP Retail  12/23/2015
# 8        2265114                     Cig/OTP Retail   2/29/2016
# 19      70159052                     Cig/OTP Retail  12/23/2015
# 20      70159056                     Cig/OTP Retail  12/23/2015
# 22       2266598                     Cig/OTP Retail    2/4/2016
# 23       2268188                     Cig/OTP Retail   2/29/2016
# 32       2011514                     Cig/OTP Retail  12/23/2015
# 35       2215438                     Cig/OTP Retail  12/17/2015
# 37      70159080                     Cig/OTP Retail  12/23/2015
# 40       2000875  Cigarette Stamping Agent & Retail   1/29/2016
# 42      70167240                     Cig/OTP Retail  12/21/2015
# 44       2265953                     Cig/OTP Retail  12/30/2015
# ...
